# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage import io, color, filters
from skimage.transform import resize, rotate
import PIL
import os
import tensorflow as tf
from skimage.color import rgb2gray

# %%
spiral_training_healthy = []
for image in os.listdir('../data/spiral/training/healthy'):
    spiral_training_healthy.append(io.imread(f'../data/spiral/training/healthy/{image}'))

spiral_training_healthy
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-9454d47578e8> in <module>
#       1 spiral_training_healthy = []
#       2 for image in os.listdir('../data/spiral/training/healthy'):
# ----> 3     spiral_training_healthy.append(io.imread(f'../data/spiral/training/healthy/{image}'))
#       4
#       5 spiral_training_healthy
#
# ~/opt/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py in imread(fname, as_gray, plugin, **plugin_args)
#      46
#      47     with file_or_url_context(fname) as fname:
# ---> 48         img = call_plugin('imread', fname, plugin=plugin, **plugin_args)
#      49
#      50     if not hasattr(img, 'ndim'):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/skimage/io/manage_plugins.py in call_plugin(kind, *args, **kwargs)
#     208                                (plugin, kind))
#     209
# --> 210     return func(*args, **kwargs)
# ...

# %%
spiral_training_parkinsons = []
for image in os.listdir('../data/spiral/training/parkinson'):
    spiral_training_parkinsons.append(io.imread(f'../data/spiral/training/parkinson/{image}'))

spiral_training_parkinsons
# Out:
# [array([[[241, 241, 241],
#          [238, 238, 238],
#          [239, 239, 239],
#          ...,
#          [236, 236, 236],
#          [230, 230, 230],
#          [227, 227, 227]],
#
#         [[239, 239, 239],
#          [239, 239, 239],
#          [237, 237, 237],
#          ...,
#          [235, 235, 235],
#          [238, 238, 238],
#          [230, 230, 230]],
#
#         [[234, 234, 234],
#          [248, 248, 248],
#          [244, 244, 244],
#          ...,
#          [231, 231, 231],
#          [245, 245, 245],
#          [242, 242, 242]],
#
#         ...,
#
#         [[242, 242, 242],
#          [238, 238, 238],
#          [242, 242, 242],
#          ...,
#          [242, 242, 242],
#          [239, 239, 239],
#          [234, 234, 234]],
#
#         [[242, 242, 242],
#          [238, 238, 238],
#          [243, 243, 243],
#          ...,
#          [231, 231, 231],
#          [243, 243, 243],
#          [243, 243, 243]],
#
#         [[242, 242, 242],
# ...

# %%
wave_training_healthy = []
for image in os.listdir('../data/wave/training/healthy'):
    wave_training_healthy.append(io.imread(f'../data/wave/training/healthy/{image}'))

wave_training_healthy
# Out:
# [array([[[242, 242, 242],
#          [237, 237, 237],
#          [243, 243, 243],
#          ...,
#          [235, 235, 235],
#          [229, 229, 229],
#          [229, 229, 229]],
#
#         [[237, 237, 237],
#          [238, 238, 238],
#          [239, 239, 239],
#          ...,
#          [235, 235, 235],
#          [239, 239, 239],
#          [229, 229, 229]],
#
#         [[240, 240, 240],
#          [229, 229, 229],
#          [229, 229, 229],
#          ...,
#          [220, 220, 220],
#          [235, 235, 235],
#          [229, 229, 229]],
#
#         ...,
#
#         [[240, 240, 240],
#          [236, 236, 236],
#          [237, 237, 237],
#          ...,
#          [228, 228, 228],
#          [231, 231, 231],
#          [229, 229, 229]],
#
#         [[236, 236, 236],
#          [234, 234, 234],
#          [239, 239, 239],
#          ...,
#          [230, 230, 230],
#          [218, 218, 218],
#          [231, 231, 231]],
#
#         [[244, 244, 244],
# ...

# %%
wave_training_parkinsons = []
for image in os.listdir('../data/wave/training/parkinson'):
    wave_training_parkinsons.append(io.imread(f'../data/wave/training/parkinson/{image}'))

wave_training_parkinsons
# Out:
# [array([[[237, 237, 237],
#          [234, 234, 234],
#          [235, 235, 235],
#          ...,
#          [234, 234, 234],
#          [231, 231, 231],
#          [230, 230, 230]],
#
#         [[235, 235, 235],
#          [234, 234, 234],
#          [234, 234, 234],
#          ...,
#          [237, 237, 237],
#          [234, 234, 234],
#          [226, 226, 226]],
#
#         [[241, 241, 241],
#          [240, 240, 240],
#          [240, 240, 240],
#          ...,
#          [242, 242, 242],
#          [245, 245, 245],
#          [233, 233, 233]],
#
#         ...,
#
#         [[243, 243, 243],
#          [240, 240, 240],
#          [240, 240, 240],
#          ...,
#          [235, 235, 235],
#          [234, 234, 234],
#          [234, 234, 234]],
#
#         [[238, 238, 238],
#          [239, 239, 239],
#          [240, 240, 240],
#          ...,
#          [240, 240, 240],
#          [237, 237, 237],
#          [236, 236, 236]],
#
#         [[235, 235, 235],
# ...
